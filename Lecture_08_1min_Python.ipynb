# %% [markdown]
# # **3️⃣ Boolean (bool)**
#
# **Boolean stores only two values:**
#
# # **True**
#
# # **False**

# %%
game_over = False
wifi_connected = True

print(game_over)
print(wifi_connected)
# Out:
# False
# True

# %% [markdown]
# # **Real Life Example**
#
# **Fan ON/OFF**
#
# **Mobile Locked/Unlocked**
#
# **Exam Passed/Failed**
#
# **Account Active/Inactive**
#
#
# #**2 possible answers.**

# %% [markdown]
# # **Important Rule**
#
# ▶ **Boolean values must**
#
# **start with a capital letter**
#
# # ✅ **Correct**

# %%
True
False

# %% [markdown]
# # **❌ Wrong**
#
# **true**
#
#
# **false**

# %% [markdown]
# # **Python will show an error.**

# %% [markdown]
# # **Beginner Example**

# %%
is_day = True

print("Is it daytime?", is_day)
# Out:
# Is it daytime? True

# %% [markdown]
# # **Output:**

# %%
Is it daytime? True
