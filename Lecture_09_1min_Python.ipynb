# %% [markdown]
# # 4️⃣ **Strings (str)**
#
# ▶  **A string means text data in Python**.
#
# ▶ **Text must be written inside quotes**.
#
# # ✅ **Example**

# %%
name = "Ali"
favorite_food = "Biryani"

print("My Name is", name)
print("I like", favorite_food)
# Out:
# My Name is Ali
# I like Biryani

# %% [markdown]
# # **Real Life Example**
#
# ▶**Your name**
#
# ▶ **City Name**
#
# ▶**Chat messages**

# %% [markdown]
# # **Important Rule**
#
# ▶ **Quotes are necessary for strings.**
#
# # ▶ **String = Quotes**
#
# # **✅ Correct**

# %%
name = "Ali"

# %% [markdown]
# # **❌ Wrong**

# %%
name = Ali

# %% [markdown]
# # **Single & Double Quotes**
#
# **Both are valid in Python**.

# %%
country = "Pakistan"
language = 'Urdu'

# %% [markdown]
# # **Both are strings ✅**
